# %% [markdown]
# # Pandas : For Data Manipulation and Data Analysis

# %%
# Multi dimentational Data structure for data analysis

# %%
# Multi dimentional data structures : data frame

# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,3,4,5], index = ['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2 = pd.Series({'Appple': 10, 'Orange': 12, 'Banana': 32})   # Created Dictionary
s2
# Out:
# Appple    10
# Orange    12
# Banana    32
# dtype: int64

# %% [markdown]
# #  Data Frame

# %%
pd.DataFrame({'Names': ['A', 'B', 'c'], 'Marks': [23,34,29]})
# Out:
#   Names  Marks
# 0     A     23
# 1     B     34
# 2     c     29

# %% [markdown]
# # Iris dataset

# %%
import csv

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\QDS'

# %%
train = pd.read_csv('Data_Train.csv')

# %%
train.head()
# Out:
#    Unique_ID              Name     Genre Country  \
# 0     413890         Hardstyle  danceedm      AU
# 1     249453        Dj Aladdin  danceedm      AU
# 2     681116  Maxximize On Air  danceedm      AU
# 3     387253       GR6 EXPLODE    rbsoul      AU
# 4    1428029          Tritonal  danceedm      AU
#
#                                            Song_Name  \
# 0  N-Vitral presents BOMBSQUAD - Poison Spitter (...
# 1          Dj Aladdin - Old School Hip Hop Quick Mix
# 2  Maxximize On Air - Mixed by Blasterjaxx - Epis...
# 3                MC Yago - Tenho Compromisso (DJ R7)
# 4                         Escape (feat. Steph Jones)
#
#                     Timestamp   Views  Comments  Likes Popularity  Followers
# 0  2018-03-30 15:24:45.000000   14017         4    499         97     119563
# 1  2016-06-20 05:58:52.000000    1918        17     49         17       2141
# 2  2015-05-08 17:45:59.000000    9668        11    312         91      22248
# ...

# %%
train.describe()   # Like Summary
# Out:
#           Unique_ID         Views       Comments     Followers
# count  7.845800e+04  7.845800e+04   78458.000000  7.845800e+04
# mean   7.451701e+05  5.469686e+05     115.270973  4.787663e+05
# std    4.805507e+05  3.883085e+06     724.614868  1.168120e+06
# min    0.000000e+00  0.000000e+00       0.000000  1.000000e+00
# 25%    3.149512e+05  6.216500e+03       1.000000  1.770000e+04
# 50%    6.618655e+05  2.538650e+04      12.000000  8.768200e+04
# 75%    1.176618e+06  1.201342e+05      61.000000  3.936550e+05
# max    1.570012e+06  1.994050e+08  104082.000000  9.789123e+06

# %%
train.iloc[0:5,[1,7,8,9]]
# Out:
#                Name  Comments  Likes Popularity
# 0         Hardstyle         4    499         97
# 1        Dj Aladdin        17     49         17
# 2  Maxximize On Air        11    312         91
# 3       GR6 EXPLODE         2  2,400         76
# 4          Tritonal        81  3,031        699

# %%
train['Comments'] > 10
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 78453     True
# 78454    False
# 78455    False
# 78456     True
# 78457    False
# Name: Comments, Length: 78458, dtype: bool

# %%
train[train['Comments'] > 10]    # Only extract tthat are true in above list
# Out:
#        Unique_ID                        Name       Genre Country  \
# 1         249453                  Dj Aladdin    danceedm      AU
# 2         681116            Maxximize On Air    danceedm      AU
# 4        1428029                    Tritonal    danceedm      AU
# 6         414871                   Hardstyle    danceedm      AU
# 10       1457484                     TWOLOUD    danceedm      AU
# ...          ...                         ...         ...     ...
# 78449     438230                     HEXAGON   deephouse      AU
# 78450     405899                    GRAVEDGR  electronic      AU
# 78452     336908                 Featurecast  electronic      AU
# 78453    1144131            Resident Advisor     ambient      AU
# 78456     175337  DHA AM (Deep House London)  electronic      AU
#
#                                                Song_Name  \
# 1              Dj Aladdin - Old School Hip Hop Quick Mix
# 2      Maxximize On Air - Mixed by Blasterjaxx - Epis...
# ...

# %%
train[(train['Comments'] < 1000) & (train['Followers'] < 100000) & (train['Genre'] == 'electronic')]
# Out:
#        Unique_ID                Name       Genre Country  \
# 12       1508244             WB x MB  electronic      AU
# 13        459831             No Mana  electronic      AU
# 35       1466298        Uprise Music  electronic      AU
# 37         66327  Uptempo HC Channel  electronic      AU
# 43       1557582          Nick Nitro  electronic      AU
# ...          ...                 ...         ...     ...
# 78428      31674           Afterlife  electronic      AU
# 78439    1393114      Beats In Space  electronic      AU
# 78440     509301     Justice Skolnik  electronic      AU
# 78450     405899            GRAVEDGR  electronic      AU
# 78452     336908         Featurecast  electronic      AU
#
#                                                Song_Name  \
# 12         WE BANG - HANDS UP - OUT NOW ON SMASHED BEATZ
# 13                           No Mana - Anti-Social Media
# 35                       Illy Noise - Comeback (VIP Mix)
# ...
